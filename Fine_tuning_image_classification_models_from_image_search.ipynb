# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadsohaib60/Fine-tuning-image-classification-models-from-image-search/blob/main/Fine_tuning_image_classification_models_from_image_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install renumics-spotlight sliceguard[all]
# Out:
# Collecting renumics-spotlight
#   Downloading renumics_spotlight-1.5.12-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 20.3 MB/s eta 0:00:00
# Collecting sliceguard[all]
#   Downloading sliceguard-0.0.32-py3-none-any.whl (29 kB)
# Collecting aiofiles (from renumics-spotlight)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.4.4)
# Collecting av (from renumics-spotlight)
#   Downloading av-11.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 49.3 MB/s eta 0:00:00
# Collecting cleanlab (from renumics-spotlight)
#   Downloading cleanlab-2.5.0-py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.5/285.5 kB 34.2 MB/s eta 0:00:00
# Collecting cleanvision (from renumics-spotlight)
#   Downloading cleanvision-0.3.4-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (8.1.7)
# Collecting databases[aiosqlite] (from renumics-spotlight)
#   Downloading databases-0.8.0-py3-none-any.whl (22 kB)
# Collecting datasets[audio]<3.0.0,>=2.12.0 (from renumics-spotlight)
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 51.6 MB/s eta 0:00:00
# Requirement already satisfied: diskcache in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (5.6.3)
# Collecting fastapi>=0.65.2 (from renumics-spotlight)
#   Downloading fastapi-0.104.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 15.4 MB/s eta 0:00:00
# Collecting filetype (from renumics-spotlight)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: h5py>3.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.9.0)
# Collecting httptools (from renumics-spotlight)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 43.7 MB/s eta 0:00:00
# Collecting httpx<0.24.0,>=0.23.0 (from renumics-spotlight)
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.6 MB/s eta 0:00:00
# Collecting imagecodecs (from renumics-spotlight)
#   Downloading imagecodecs-2023.9.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.31.6)
# Collecting importlib_resources<5.8.0 (from renumics-spotlight)
#   Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.1.2)
# Collecting loguru (from renumics-spotlight)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.2.1)
# Collecting numba<0.58.0,>=0.57.1 (from renumics-spotlight)
#   Downloading numba-0.57.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 97.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.23.5)
# Collecting orjson (from renumics-spotlight)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.5.3)
# Collecting pillow<11.0.0,>=10.0.0 (from renumics-spotlight)
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 101.3 MB/s eta 0:00:00
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.9.0)
# Collecting py-machineid (from renumics-spotlight)
#   Downloading py_machineid-0.4.6-py3-none-any.whl (4.6 kB)
# Collecting pydantic<3.0.0,>=2.0.0 (from renumics-spotlight)
#   Downloading pydantic-2.5.1-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.6/381.6 kB 47.5 MB/s eta 0:00:00
# Collecting pydantic-settings<3.0.0,>=2.0.3 (from renumics-spotlight)
#   Downloading pydantic_settings-2.1.0-py3-none-any.whl (11 kB)
# Collecting pygltflib>=1.15.1 (from renumics-spotlight)
#   Downloading pygltflib-1.16.1.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.31.0)
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.9)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.19.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (67.7.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.66.1)
# Collecting trimesh (from renumics-spotlight)
#   Downloading trimesh-4.0.4-py3-none-any.whl (688 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.2/688.2 kB 63.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.5.0)
# Collecting umap-learn (from renumics-spotlight)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting uvicorn>=0.22 (from renumics-spotlight)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 8.8 MB/s eta 0:00:00
# Collecting uvloop>=0.17.0 (from renumics-spotlight)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 108.8 MB/s eta 0:00:00
# Collecting validators (from renumics-spotlight)
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting websockets (from renumics-spotlight)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 21.6 MB/s eta 0:00:00
# Collecting hnne>=0.1.10 (from sliceguard[all])
#   Downloading hnne-0.1.10-py3-none-any.whl (19 kB)
# Collecting pandas (from renumics-spotlight)
#   Downloading pandas-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 80.7 MB/s eta 0:00:00
# Collecting fairlearn>=0.8.0 (from sliceguard[all])
#   Downloading fairlearn-0.9.0-py3-none-any.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.5/231.5 kB 28.9 MB/s eta 0:00:00
# Collecting scikit-learn (from renumics-spotlight)
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 101.9 MB/s eta 0:00:00
# Collecting puremagic>=1.15 (from sliceguard[all])
#   Downloading puremagic-1.15-py3-none-any.whl (32 kB)
# Collecting flaml>=2.0.0 (from sliceguard[all])
#   Downloading FLAML-2.1.1-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 36.9 MB/s eta 0:00:00
# Collecting xgboost<2.0.0,>=1.7.6 (from sliceguard[all])
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: transformers[torch]>=4.30.2 in /usr/local/lib/python3.10/dist-packages (from sliceguard[all]) (4.35.2)
# Collecting sentence-transformers>=2.2.1 (from sliceguard[all])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchaudio>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from sliceguard[all]) (2.1.0+cu118)
# Collecting bing-image-downloader==1.1.2 (from sliceguard[all])
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (9.0.0)
# Collecting pyarrow-hotfix (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading pyarrow_hotfix-0.5-py3-none-any.whl (7.8 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.4.1)
# Collecting multiprocess (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.19.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (6.0.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.12.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.10.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fairlearn>=0.8.0->sliceguard[all]) (1.11.3)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.65.2->renumics-spotlight) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.65.2->renumics-spotlight)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 10.7 MB/s eta 0:00:00
# Collecting typing-extensions (from renumics-spotlight)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting pynndescent (from hnne>=0.1.10->sliceguard[all])
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 78.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from hnne>=0.1.10->sliceguard[all]) (0.9.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from hnne>=0.1.10->sliceguard[all]) (3.0.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (2023.7.22)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx<0.24.0,>=0.23.0->renumics-spotlight)
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 10.8 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3 (from httpx<0.24.0,>=0.23.0->renumics-spotlight)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (1.3.0)
# Collecting pillow<11.0.0,>=10.0.0 (from renumics-spotlight)
#   Downloading Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 98.0 MB/s eta 0:00:00
# Collecting llvmlite<0.41,>=0.40.0dev0 (from numba<0.58.0,>=0.57.1->renumics-spotlight)
#   Downloading llvmlite-0.40.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->renumics-spotlight) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->renumics-spotlight) (2023.3.post1)
# Collecting tzdata>=2022.1 (from pandas->renumics-spotlight)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 41.8 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3.0.0,>=2.0.0->renumics-spotlight)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.3 (from pydantic<3.0.0,>=2.0.0->renumics-spotlight)
#   Downloading pydantic_core-2.14.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 82.3 MB/s eta 0:00:00
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.0.3->renumics-spotlight)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting dataclasses-json>=0.0.25 (from pygltflib>=1.15.1->renumics-spotlight)
#   Downloading dataclasses_json-0.6.2-py3-none-any.whl (28 kB)
# Collecting deprecated (from pygltflib>=1.15.1->renumics-spotlight)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->renumics-spotlight) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->renumics-spotlight) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->renumics-spotlight) (2.0.7)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->renumics-spotlight) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->renumics-spotlight) (3.2.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->sliceguard[all]) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->sliceguard[all]) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->sliceguard[all]) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=2.2.1->sliceguard[all])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->sliceguard[all]) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->sliceguard[all]) (1.12)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->sliceguard[all]) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]>=4.30.2->sliceguard[all]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]>=4.30.2->sliceguard[all]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]>=4.30.2->sliceguard[all]) (0.4.0)
# Collecting accelerate>=0.20.3 (from transformers[torch]>=4.30.2->sliceguard[all])
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 32.5 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn>=0.22->renumics-spotlight)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cleanlab->renumics-spotlight) (2.3.0)
# Requirement already satisfied: tabulate>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from cleanvision->renumics-spotlight) (0.9.0)
# Collecting imagehash>=4.2.0 (from cleanvision->renumics-spotlight)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cleanvision->renumics-spotlight) (3.7.1)
# Collecting sqlalchemy<1.5,>=1.4.42 (from databases[aiosqlite]->renumics-spotlight)
#   Downloading SQLAlchemy-1.4.50-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.4 MB/s eta 0:00:00
# Collecting aiosqlite (from databases[aiosqlite]->renumics-spotlight)
#   Downloading aiosqlite-0.19.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->renumics-spotlight) (2.1.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->renumics-spotlight) (0.2.10)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa->renumics-spotlight) (0.5.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (1.4.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]>=4.30.2->sliceguard[all]) (5.9.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.65.2->renumics-spotlight) (1.1.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.1 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.3.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->renumics-spotlight) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->renumics-spotlight) (6.3.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->renumics-spotlight)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->renumics-spotlight) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<1.5,>=1.4.42->databases[aiosqlite]->renumics-spotlight) (3.0.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.5.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->pygltflib>=1.15.1->renumics-spotlight) (1.14.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.0.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.0.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.18.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (4.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.1->sliceguard[all]) (1.3.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.12.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.6.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.5.1)
# Building wheels for collected packages: pygltflib, sentence-transformers, umap-learn, pynndescent
#   Building wheel for pygltflib (setup.py) ... done
#   Created wheel for pygltflib: filename=pygltflib-1.16.1-py3-none-any.whl size=27086 sha256=3acd230679dd752d69038f68538476416a3c2a9b659acc6265164d16568491b3
#   Stored in directory: /root/.cache/pip/wheels/9c/73/91/ae3a93bb6cc6dde662ed1dc48dd0ec7ca41a7bcc2a1a99b5a6
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=fea3f9e4c9af714663b1122caac313a70021790ef2a7216d78bb5fe312d3c87d
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86831 sha256=22b58719fbf2a1238478d0dd3b4e4db162e61d973382fe2cc8ddb8c0b0e1392a
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=c1293939d50c25de248d1ed4ca980760e53ac81f16ff0135beaa5082db7a7065
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built pygltflib sentence-transformers umap-learn pynndescent
# Installing collected packages: sentencepiece, rfc3986, py-machineid, puremagic, filetype, bing-image-downloader, websockets, validators, uvloop, tzdata, typing-extensions, trimesh, sqlalchemy, python-dotenv, pyarrow-hotfix, pillow, orjson, mypy-extensions, marshmallow, loguru, llvmlite, jedi, importlib_resources, imagecodecs, httptools, h11, flaml, dill, deprecated, av, annotated-types, aiosqlite, aiofiles, xgboost, uvicorn, typing-inspect, starlette, scikit-learn, pydantic-core, pandas, numba, multiprocess, imagehash, httpcore, databases, pynndescent, pydantic, httpx, fairlearn, dataclasses-json, cleanvision, cleanlab, accelerate, umap-learn, pygltflib, pydantic-settings, hnne, fastapi, datasets, sentence-transformers, renumics-spotlight, sliceguard
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.23
#     Uninstalling SQLAlchemy-2.0.23:
#       Successfully uninstalled SQLAlchemy-2.0.23
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.41.1
#     Uninstalling llvmlite-0.41.1:
#       Successfully uninstalled llvmlite-0.41.1
#   Attempting uninstall: importlib_resources
#     Found existing installation: importlib-resources 6.1.1
#     Uninstalling importlib-resources-6.1.1:
#       Successfully uninstalled importlib-resources-6.1.1
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.2
#     Uninstalling xgboost-2.0.2:
#       Successfully uninstalled xgboost-2.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: numba
#     Found existing installation: numba 0.58.1
#     Uninstalling numba-0.58.1:
#       Successfully uninstalled numba-0.58.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.3 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.50 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed accelerate-0.24.1 aiofiles-23.2.1 aiosqlite-0.19.0 annotated-types-0.6.0 av-11.0.0 bing-image-downloader-1.1.2 cleanlab-2.5.0 cleanvision-0.3.4 databases-0.8.0 dataclasses-json-0.6.2 datasets-2.15.0 deprecated-1.2.14 dill-0.3.7 fairlearn-0.9.0 fastapi-0.104.1 filetype-1.2.0 flaml-2.1.1 h11-0.14.0 hnne-0.1.10 httpcore-0.16.3 httptools-0.6.1 httpx-0.23.3 imagecodecs-2023.9.18 imagehash-4.3.1 importlib_resources-5.7.1 jedi-0.19.1 llvmlite-0.40.1 loguru-0.7.2 marshmallow-3.20.1 multiprocess-0.70.15 mypy-extensions-1.0.0 numba-0.57.1 orjson-3.9.10 pandas-2.1.3 pillow-10.0.1 puremagic-1.15 py-machineid-0.4.6 pyarrow-hotfix-0.5 pydantic-2.5.1 pydantic-core-2.14.3 pydantic-settings-2.1.0 pygltflib-1.16.1 pynndescent-0.5.10 python-dotenv-1.0.0 renumics-spotlight-1.5.12 rfc3986-1.5.0 scikit-learn-1.3.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 sliceguard-0.0.32 sqlalchemy-1.4.50 starlette-0.27.0 trimesh-4.0.4 typing-extensions-4.8.0 typing-inspect-0.9.0 tzdata-2023.3 umap-learn-0.5.5 uvicorn-0.24.0.post1 uvloop-0.19.0 validators-0.22.0 websockets-12.0 xgboost-1.7.6

# %%
from renumics import spotlight
from sliceguard.data import create_imagedataset_from_bing
from sliceguard.models.huggingface import finetune_image_classifier, generate_image_pred_probs_embeddings
from sliceguard.embeddings import generate_image_embeddings

# Create an Image Dataset from Bing Image Search
class_names = ["Blue Tang", "Clownfish", "Spotted Eagle Ray", "Longnose Butterfly Fish", "Moorish Idol", "Royal Gramma Fish"]
df = create_imagedataset_from_bing(class_names, 25, "data", test_split=0.2, license="Free to share and use")

# Fine-tune a ViT Model with the data (in 1-2 minutes on a GPU)
finetune_image_classifier(df[df["split"] == "train"], model_name="google/vit-base-patch16-224-in21k", output_model_folder="./model_folder", epochs=15)
df["prediction"], df["probs"], df["embeddings"] = generate_image_pred_probs_embeddings(   df["image"].values, model_name="./model_folder")

# Check the result and detect problematic clusters
spotlight.show(df, layout="https://spotlight.renumics.com/resources/image_classification_v1.0.json")
# Out:
# [%] Downloading Images to /content/data/Blue Tang
#
#
# [!!]Indexing page: 1
#
# [%] Indexed
jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://t00.deviantart.net/8hkNH1yAPNjXwQEoF2jtotz85eY=/300x200/filters:fixed_height(100,100):origin()/pre00/c32d/th/pre/i/2012/099/e/a/wild_flowers_by_crazyemofreak-d4vkxqc.jpg
# [!] Issue getting: https://t00.deviantart.net/8hkNH1yAPNjXwQEoF2jtotz85eY=/300x200/filters:fixed_height(100,100):origin()/pre00/c32d/th/pre/i/2012/099/e/a/wild_flowers_by_crazyemofreak-d4vkxqc.jpg
# [!] Error:: HTTP Error 503: Service Unavailable
# [%] Downloading Image #25 from https://t00.deviantart.net/yI1EyGllWeBnG28gaIw6Dl7VKKs=/300x200/filters:fixed_height(100,100):origin()/pre00/d92e/th/pre/i/2012/099/3/3/orchids_by_crazyemofreak-d4vky5t.jpg
# [!] Issue getting: https://t00.deviantart.net/yI1EyGllWeBnG28gaIw6Dl7VKKs=/300x200/filters:fixed_height(100,100):origin()/pre00/d92e/th/pre/i/2012/099/3/3/orchids_by_crazyemofreak-d4vky5t.jpg
# [!] Error:: HTTP Error 503: Service Unavailable
# [%] Downloading Image #25 from http://c1.staticflickr.com/4/3011/2554398668_31fd5d5b06.jpg
# [Error]Invalid image, not saving http://c1.staticflickr.com/4/3011/2554398668_31fd5d5b06.jpg
#
# [!] Issue getting: http://c1.staticflickr.com/4/3011/2554398668_31fd5d5b06.jpg
# [!] Error:: Invalid image, not saving http://c1.staticflickr.com/4/3011/2554398668_31fd5d5b06.jpg
#
# [%] Downloading Image #25 from http://t05.deviantart.net/IOeyNCEwI-oXMg49U92zeuEyxaU=/300x200/filters:fixed_height(100,100):origin()/pre00/0e16/th/pre/i/2013/116/d/f/d_r_a_g_o_n___p_0_p_by_missmachineart-d633mq6.jpg
# [!] Issue getting: http://t05.deviantart.net/IOeyNCEwI-oXMg49U92zeuEyxaU=/300x200/filters:fixed_height(100,100):origin()/pre00/0e16/th/pre/i/2013/116/d/f/d_r_a_g_o_n___p_0_p_by_missmachineart-d633mq6.jpg
# [!] Error:: HTTP Error 503: Service Unavailable
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 25 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #25 from https://aquariumandfishes.com/wp-content/uploads/2020/08/Royal-Gramma3-2048x1536.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 25 images.
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='14' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14/15 1:02:54 < 05:14, 0.00 it/s, Epoch 13/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.745974</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.703753</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.628386</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.564716</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.508603</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>1.457839</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>1.411738</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.370398</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.333560</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>1.301318</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>1.273725</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>1.250946</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='2' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/4 00:19 < 00:39, 0.05 it/s]
#     </div>
#     <div>
#
#       <progress value='15' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15/15 1:14:48, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.745974</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.703753</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.628386</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.564716</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.508603</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>1.457839</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>1.411738</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.370398</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.333560</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>1.301318</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>1.273725</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>1.250946</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>1.233316</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>1.221247</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>1.215056</td>
#     </tr>
#   </tbody>
# </table><p>
# Probability computation on cpu with batch size 1 and multiprocessing None.
# Map:   0%|          | 0/148 [00:00<?, ? examples/s]
# Embedding computation on cpu with batch size 1 and multiprocessing None.
# Some weights of ViTModel were not initialized from the model checkpoint at ./model_folder and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/148 [00:00<?, ? examples/s]
# http://127.0.0.1:39355/

# %%
# Create an Image Dataset from Bing
class_names = [
    "Blue Tang",
    "Clownfish",
    "Spotted Eagle Ray",
    "Longnose Butterfly Fish",
    "Moorish Idol",
    "Royal Gramma Fish",
]
df = create_imagedataset_from_bing(
    class_names, 25, "data", test_split=0.2, license="Free to share and use"
)
# Out:
# [%] Downloading Images to /content/data/Clownfish
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/b/bf/Clown_fish.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /content/data/Longnose Butterfly Fish
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://fishesofaustralia.net.au/images/image/ChaetodonLunulatusRLS.jpg
# [!] Issue getting: http://fishesofaustralia.net.au/images/image/ChaetodonLunulatusRLS.jpg
# [!] Error:: The read operation timed out
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #1 from https://img1.whatsthatfish.com/unsafe/810x540/image.whatsthatfish.com/original/072016/03X6SY33sT.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.

# %%
finetune_image_classifier(
    df[df["split"] == "train"],
    model_name="google/vit-base-patch16-224-in21k",
    output_model_folder="./model_folder",
    epochs=15,
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='3' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3/15 05:31 < 1:06:15, 0.00 it/s, Epoch 2/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.781945</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.739772</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='15' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15/15 1:18:14, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.781945</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.739772</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.664824</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.600943</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.545947</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>1.495914</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>1.448048</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.403668</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.364946</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>1.332388</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>1.304625</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>1.281601</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>1.263786</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>1.251614</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>1.245337</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
df["prediction"], df["probs"], df["embeddings"] = generate_image_pred_probs_embeddings(
    df["image"].values, model_name="./model_folder"
)
# Out:
# Probability computation on cpu with batch size 1 and multiprocessing None.
# Map:   0%|          | 0/148 [00:00<?, ? examples/s]
# Embedding computation on cpu with batch size 1 and multiprocessing None.
# Some weights of ViTModel were not initialized from the model checkpoint at ./model_folder and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/148 [00:00<?, ? examples/s]

# %%
# !pip install spotlight
# Out:
# Collecting spotlight
#   Downloading spotlight-3.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: spotlight
# Successfully installed spotlight-3.3.0

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.0.1.tar.gz (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.8/731.8 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-7.0.1-py3-none-any.whl size=21122 sha256=cb68ef96f04eaea947d2bdaf8e7399ef95305a832dce7ede1c06bfa5beaaf0c5
#   Stored in directory: /root/.cache/pip/wheels/3b/32/0e/27789b6fde02bf2b320d6f1a0fd9e1354b257c5f75eefc29bc
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.0.1

# %%
# !pip install pyngrok==7.0.1

from pyngrok import ngrok
import IPython

# Set up the ngrok tunnel
public_url = ngrok.connect()

# Display the public URL in the notebook
public_url_str = str(public_url)
IPython.display.HTML(f"Ngrok Tunnel is active: <a href='{public_url_str}' target='_blank'>{public_url_str}</a>")
# Out:
# Requirement already satisfied: pyngrok==7.0.1 in /usr/local/lib/python3.10/dist-packages (7.0.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok==7.0.1) (6.0.1)
# Ngrok Tunnel is active: <a href='NgrokTunnel: "https://3d67-34-150-210-228.ngrok.io" -> "http://localhost:80"' target='_blank'>NgrokTunnel: "https://3d67-34-150-210-228.ngrok.io" -> "http://localhost:80"</a>

# %%
spotlight.show(
    df, layout="https://spotlight.renumics.com/resources/image_classification_v1.0.json"
)
# Out:
# http://127.0.0.1:41135/
